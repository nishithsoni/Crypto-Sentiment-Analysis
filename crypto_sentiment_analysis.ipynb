# %% [markdown]
# Twitter-Crypto Popularity Predictor
#
# 10/30/21
#
# By: Jaden L, Nishith S, Satvik R, & Rohan B
#
# i. Boiler Plate, authorization

# %%
import tweepy as twp
from textblob import TextBlob
from keys_and_tokens import API_KEY, API_KEY_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET

auth = twp.OAuthHandler(API_KEY, API_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = twp.API(auth)

# %% [markdown]
# ii. Finding Magnitude

# %%
# My Functions

def get_polarity(tweet):
    #return TextBlob.sentiments.(tweet)
    return TextBlob(tweet).sentiment.polarity


def get_sentiment(score):
  if score < 0:
    return 'Negative'
  elif score == 0:
    return 'Neutral'
  else:
    return 'Positive'


def find_account_value(tweet):
    #check verification
    #check followers
    value = 1
    ver = tweet.user.verified
    if(ver == True):
        value *= 1.10
    elif(tweet.user.followers_count > 100000):
        value *= 1.05
    else:
        value += 0.05
    return value


#Fids value/impact of a single tweet
#param: tweet - item: full item of all data regarding current tweet
#param: list_of_tweets - int: a full list of tweets with all information regarding likes, user, retweets, etc.
def find_tweet_value(list_of_tweets, tweet):

    # getting tweet_likes
    tweet_likes = tweet.favorite_count
    tweet_rts = tweet.retweet_count

    #calculating averages
    total_likes = 0
    total_rts = 0
    for tweet in list_of_tweets:
        total_likes += tweet.favorite_count
        total_rts += tweet.retweet_count

    avg_likes = total_likes / len(list_of_tweets)
    avg_rts = total_rts / len(list_of_tweets)

    #initializing value
    value = 5

    #checking likes alt
    if tweet_likes > avg_likes:
        value += tweet_likes / avg_likes
    elif tweet_likes < avg_likes:
        value -= tweet_likes / avg_likes

    #checking retweets
    if tweet_rts > avg_rts:
        value += tweet_rts / avg_rts
    elif tweet_rts < avg_rts:
        value -= tweet_rts / avg_rts


    return value


def get_magnitude(list_of_tweets, tweet):
    pol = get_polarity(tweet.text)
    sen = get_sentiment(pol)

    if(sen == "Negative"):
        mag = find_account_value(tweet) + find_tweet_value(list_of_tweets, tweet) * -1
    elif(sen == "Neutral"):
        mag = 0
    else:
        mag = find_account_value(tweet) + find_tweet_value(list_of_tweets, tweet)

    return mag


def get_connotation(list_of_tweets):
    con = 0
    for tweet in list_of_tweets:
        con += get_magnitude(list_of_tweets, tweet)
    return con


#loops through tweets and prints all information regarding tweet
#param: list_of_tweets - int: a full list of tweets with all information regarding likes, user, retweets, etc.
def print_all_tweets(list_of_tweets):

    for tweet in list_of_tweets:
        tweet_value = find_tweet_value(list_of_tweets, tweet) #finding tweet value
        acc_value = find_account_value(tweet) #finding account value
        magnitude = get_magnitude(list_of_tweets, tweet)
        print(f"Verified: {tweet.user.verified}")
        print(f"{tweet.user.screen_name} tweeted: ") #prints username
        print("-----")
        print(tweet.text) #prints actual tweet text
        print("-----")
        print(f"# of likes: {tweet.favorite_count}") #prints likes
        print(f'# of retweets: {tweet.retweet_count}') #prints retweets
        print(f"Tweet Value: {tweet_value}") #prints tweet value
        print(f"Account Value: {acc_value}") #prints account value
        print(f"Tweet Magnitude: {magnitude}")

        #getting sentiment
        pol = get_polarity(tweet.text)
        sen = get_sentiment(pol)
        print(f"Sentiment: {sen}") #prints sentiment

        print("-------------------------------------------------------------------------------") #seperates each tweet


#main function
def main():
    # user input
    user_search = input("What coin are you looking for? ")
    search_term = user_search + " -filter:retweets"

    # making a list of all tweets with my query
    search_tweets = api.search_tweets(q = search_term, lang = "en", count = 100000, result_type = "mixed")


    # shows me how many tweets api.search_tweets() gets
    print(user_search.upper())
    print(f"Number of tweets found: {len(search_tweets)}")
    print("------------------------------------------------------------------------------------------------------------------------")

    # loops through each tweet in search_tweets and prints information about each tweet
    print_all_tweets(search_tweets)

    connotation = get_connotation(search_tweets)
    print(f"CURRENT CONNOTATION: {connotation}")


main()
# Out:
# BITCOIN
# Number of tweets found: 97
# ------------------------------------------------------------------------------------------------------------------------
# Verified: True
# BitcoinMagazine tweeted:
# -----
# JUST IN – Rio De Janeiro mayor announces 10% discount on taxes paid in #Bitcoin 🇧🇷 https://t.co/wsfdqcdEFn
# -----
# # of likes: 11337
# # of retweets: 2180
# Tweet Value: 74.70907941696058
# Account Value: 1.1
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: True
# saylor tweeted:
# -----
# #Bitcoin is the future of the #Internet.  https://t.co/CdABn8dIsw
# -----
# # of likes: 11330
# # of retweets: 2496
# Tweet Value: 79.94335050740442
# Account Value: 1.1
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: True
# francis_ngannou tweeted:
# -----
# Been talking with my family and friends in the crypto space. #Bitcoin is huge in Africa and I’m thinking of taking… https://t.co/KlFLshis9C
# -----
# # of likes: 10181
# # of retweets: 1151
# Tweet Value: 54.18581965761282
# Account Value: 1.1
# Tweet Magnitude: 55.28581965761282
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# DerekTMcKinney tweeted:
# -----
# 🤓🤔👍 #knownews #bitcoin #eth Shiba Inu finds support at this level and could head into an accumulation zone Shiba https://t.co/S5Gr6hRwt7
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# VCapitalist25 tweeted:
# -----
# @DingPongChong @Freelanceclark1 @Bitcoin_Rob @CoffeeOrDieMag @nolanwpeterson Syria, Libya, which else? Oh yeah, Joe… https://t.co/6ynylZbWCq
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# NUKnoE tweeted:
# -----
# Me Now: Bitcoin my nigha!!! Drop all your change into it and don't touch it till Ü hit 35.
#
# Past Me: "What the fawk… https://t.co/6g4fC19ZlA
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# NFTkaStat tweeted:
# -----
# weak to buy this art?    https://t.co/BsDE5xalv9
# #NFTGiveaway #NFTCommunity #NFTCollector #NFTs #Discord #Ethereum… https://t.co/LUcP2xOtj3
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# DerekTMcKinney tweeted:
# -----
# 🤓🤔👍 #knownews #bitcoin #eth Changpeng Zhao Reveals The Magic Behind Binance’s Huge Success In Recent Years Binance https://t.co/uoJVsRo3lt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# TruthDiscerned tweeted:
# -----
# @Suriname_Boss @STEALTHxJ @francis_ngannou @ufc And why would the richest people in the world who are invested in a… https://t.co/KkYzArqSeJ
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Long_Irish_l_F tweeted:
# -----
# @ATLHawks @TheTraeYoung Hello, my name is Mr Irish and I wanna give my testimony from Crypto Currency Trading also… https://t.co/6G2mUIDS8K
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# SadieGrubor tweeted:
# -----
# @Bitcoin Hi, nice to be your friend. We can discuss the knowledge of ETH and digital currency together. Manipulate… https://t.co/P9lcbvgN3A
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# btc_status tweeted:
# -----
# 📊 Bitcoin Network Status
#
# Price: $43,404
# Pooled Tx: 11,100
# Avg. Block: 8 min 28 s (-15.34%)
# Hash Rate: 186.58 EH/s… https://t.co/Gdc621e4yp
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.997048891052359
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# username_Dizzy tweeted:
# -----
# @pewtergod @spiny_lobe_fish @dappergander You do realize the first internet ready digital currencies were up and ru… https://t.co/vzxq4Pj6pt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Crypto_goup tweeted:
# -----
# #Crypto #shıb #Bitcoin #BTC #bnb #eth #ada #atom #xrp #xlm #lınk #xtz #dot #eos #doge #band #sxp #neo #kripto #kava… https://t.co/P92N0UFcRl
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.997048891052359
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Hassan67198878 tweeted:
# -----
# @BluesparrowC @elonmusk @BillyM2k @BlueSparrowETH The best 1000x NFT token is #bluesparrow
# Why?
# KYC Done
# Ownership… https://t.co/P97vesPptH
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# InsanityRules tweeted:
# -----
# @MSOElevator Their two biggest industries are cyber-ransom and mining Bitcoin. Pretty ironic really.
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# bitcoinvaluebot tweeted:
# -----
# Current Bitcoin Price
# All Forks = $43,929.33 📈 0.19%
# --
# $BTC = $43,424.81 📈 0.19%
# $BCH = $390.78 📈 0.05%
# $BSV = $113.74 📈 0.22%
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# btctrek tweeted:
# -----
# #Bitcoin is the natural immune response, of the financial system, to #corruption and deceit. #BTC
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.997048891052359
# Account Value: 1.05
# Tweet Magnitude: 6.047048891052359
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# johnbelgravia tweeted:
# -----
# we are in the midst of the
#
# World War III
#
# and #bitcoin is our weapon of mass destruction
#
# it will set the peopl… https://t.co/N4AkdmAPp9
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.997048891052359
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Long_Irish_l_F tweeted:
# -----
# @ATLHawks @jcollins20_ Hello, my name is Mr Irish and I wanna give my testimony from Crypto Currency Trading also k… https://t.co/G0RgY0U3TC
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# J___G____ tweeted:
# -----
# New crypto #giveaway! I will send you .1 BTC if we reach 45,000 this weekend, JUST LIKE ❤️ to enter. I’m paying it… https://t.co/RyEwSKjgPa
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.997048891052359
# Account Value: 1.05
# Tweet Magnitude: 6.047048891052359
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# steve_alarm tweeted:
# -----
# @allstarcharts I would say it ends at peak madness. When Max Keiser's   El Salavador Bitcoin volcano bonds are goin… https://t.co/gRpTb3rfRW
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# ViaforaCrypto tweeted:
# -----
# 💰 CRYPTO BUYS (01/15/2022 13:01)
# - Harmony: $0.339
# - Decred: $69.532
# - Harmony: $0.339
# #Harmony #Decred #Harmony… https://t.co/CekqETQC8N
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# cryptoalerts911 tweeted:
# -----
# The Fear Around $41,000 Bitcoin Is A Sign Of Success || #CryptoNews #cryptocurrencies https://t.co/hweeBLzK0M
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: True
# cefeche tweeted:
# -----
# In El Salvador, Bitcoin’s Libertarian Streak Meets an Autocratic Regime https://t.co/biuoUwGcWt via @wired
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.997048891052359
# Account Value: 1.1
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# cryptodev93 tweeted:
# -----
# @Bitboy_Crypto Ahann!! Pay your mobile bills from Quppy app!! @QuppyPay
# Top up your Mobile phone with crypto and fi… https://t.co/f1g7u4SeZt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# TechDev_52 tweeted:
# -----
# Historically significant #Bitcoin cycle fib / log regression curve crosses. https://t.co/znWgvzMgMM
# -----
# # of likes: 5
# # of retweets: 0
# Tweet Value: 4.985244455261797
# Account Value: 1.05
# Tweet Magnitude: 6.035244455261797
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# serif85 tweeted:
# -----
# #dexgame blockchain-based next-generation gaming platform and gaming exchange. DexGame's goal is to create a decent… https://t.co/YNvyARihAm
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.997048891052359
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# FanPokmi tweeted:
# -----
# Stop using Bitcoin SV ! Try to buy 94380 $PKN instead !!! #PKN #pokmi #PokenArmy #poken #PokenArmyProgram
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Godswill500 tweeted:
# -----
# @myairdrop_ A Magnificent project with great futuristic potentials guys
# I so much love this project
# I hope to achi… https://t.co/tO3B4seneK
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Audacitycap tweeted:
# -----
# What time frame works best for your strategy?
#
# #forex #forextrader #bitcoin #trading #forextrading #money… https://t.co/8F0ffdNAFe
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.997048891052359
# Account Value: 1.05
# Tweet Magnitude: 6.047048891052359
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Altcoin_Troy tweeted:
# -----
# #BTC #Bitcoin
#
# The weekly Bollinger Bands have been a great tool to monitor market swings.
#
# Think worst case we see… https://t.co/STiMHjL36v
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.997048891052359
# Account Value: 1.05
# Tweet Magnitude: -3.9470488910523596
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# Hassan67198878 tweeted:
# -----
# @BluesparrowC @elonmusk @BillyM2k @BlueSparrowETH The best 1000x NFT token is #bluesparrow
# Why?
# KYC Done
# Ownership… https://t.co/knV06qreyB
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# weeblueghost tweeted:
# -----
# -
# BTC price: $43,404 / £31,738
#
# 23.04 Naks per USD
# 31.51 Naks per GBP
#
# &lt;price steady&gt;
#
# A #Nak is one millionth o… https://t.co/yJflJ4dmVj
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# lala44black tweeted:
# -----
# @WapSwapFinance I advise everyone to this successful project, which is very promising and will bring good returns t… https://t.co/SJW4xAeHpY
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# parsehfarzad tweeted:
# -----
# @BluesparrowC @binance @BlueSparrowETH Don’t cry because it’s over. Smile because it happened, #bluesparrow came…… https://t.co/9SH57pF13y
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# ShareenMckinne1 tweeted:
# -----
# @bitchcoinempire @NickAdamsinUSA This from a bitcoin peddler?😂😂😂😂😂
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# CryptoDigiCurr1 tweeted:
# -----
# El Salvador is down $12 million on its Bitcoin buys https://t.co/8qsZrLtW87
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# RL19M tweeted:
# -----
# @roy250swb It's just a matter of time. #Bitcoin will fix that 😉
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# CryptoDigiCurr1 tweeted:
# -----
# Bitcoin’s Hashrate Taps New Lifetime High, BTC Price 20% Above Production Cost, Difficulty Nears ATH https://t.co/5QYkC3kbw6
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# afiqazni tweeted:
# -----
# Inflation steals your money, time, freedom, energy, sacrifices, future &amp; lifetime.
#
# It's not just a silent robbery,… https://t.co/nze6NqBS6g
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Hassan67198878 tweeted:
# -----
# @BluesparrowC @elonmusk @BillyM2k @BlueSparrowETH The best 1000x NFT token is #bluesparrow
# Why?
# KYC Done
# Ownership… https://t.co/7eJFDNWFNv
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# WorldCoinIndex tweeted:
# -----
# Bitcoin price index https://t.co/o7UcHJUhC6 #USD #EUR #CNY #GBP #RUB https://t.co/ATkl9OJqwo
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# gegelsmr2 tweeted:
# -----
# Ok
#
# I'm trying @JohnOnChain bot on @LNMarkets
#
# Basically, I have a list of plebs, every time they tweet with "Bitc… https://t.co/NGJncspfeB
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# qedrico tweeted:
# -----
# @JeffBooth Bitcoin is fantastic but to deny the potential of all other blockchains is immensely short sighted.
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Saddam1821 tweeted:
# -----
# @airdropinspect Very good project &amp; iam expect this project. My best wishes for this project.
# @Minhaj01911… https://t.co/yH6Te9NLUX
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# iAsaadb tweeted:
# -----
# Time favors #Bitcoin
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# psalm911lisa tweeted:
# -----
# The Most Important Investment You Can Make Is In Yourself   https://t.co/5iZAJDywXT
# #Crypto #CryptoCurrency… https://t.co/hQssrV3wWi
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# CurrencyNews tweeted:
# -----
# Bitcoin, Ethereum, Cardano Continue Positive Push This Weekend - Motley Fool https://t.co/gdqDdxrsD3… https://t.co/JLBRFDCpqO
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Justin_cryptoo tweeted:
# -----
# @SpyWolf1Fan @davidgokhshtein @SpyWolfNetwork Fear the day you are surrounded by a pack of wolves. Escape as long a… https://t.co/7COJnnYXuI
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# diorreah tweeted:
# -----
# -9.166666666666666 degrees
# @elonmusk fix bitcoin
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# RobiulRazz tweeted:
# -----
# @AquaBitAirdrop DYOR! for all the projects you want to join. but for you my friends, I recommend this project and l… https://t.co/uCuruDdXX8
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# AvicennaCapital tweeted:
# -----
# #Bitcoin had a rocky start to 2022, but it appears to have stabilized this week. Now, some analysts are predicting… https://t.co/7GyGwUZL1V
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# physixchimp tweeted:
# -----
# @Bitcoin Until it isn't anymore
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# r_topisto tweeted:
# -----
# #computerart #creativecoding #generativeart :
# #bitcoin #blockchain 's
# LAST Block, Height : 718837
# [ See more on… https://t.co/aXKrH33fPj
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# MarketChartsApp tweeted:
# -----
# #BTCUSDT - New Technical Analysis
#
# Chart on TradingView https://t.co/ecR28JQAUJ $BTC $ETH #Bitcoin #CryptoCurrency… https://t.co/79MQRH3viF
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Ali1989Sirik12 tweeted:
# -----
# @SpyWolf1Fan @SpyWolfNetwork When wolves decide to hunt. There is no chance for prey. They waked up and smell the p… https://t.co/zRUthuGXLO
# -----
# # of likes: 1
# # of retweets: 1
# Tweet Value: 4.980419369365406
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# cryptocharts tweeted:
# -----
# Thoughts on $BTC #Bitcoin! See saeid_zirak98's idea on TradingView below. https://t.co/6ILrSKSDUN
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Rachelle0018 tweeted:
# -----
# @ghostXperiment @bitcoin_ken @SimonSvatos1 It is. Little boys hate stronger women.
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# Hassan67198878 tweeted:
# -----
# @BluesparrowC @elonmusk @BillyM2k @BlueSparrowETH The best 1000x NFT token is #bluesparrow
# Why?
# KYC Done
# Ownership… https://t.co/hcqDlDUWwW
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.997048891052359
# Account Value: 1.05
# Tweet Magnitude: 6.047048891052359
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# choosefreedomOG tweeted:
# -----
# Tonga announces #bitcoin will become legal tender and then a “giant exploding underwater volcano” wipes out the isl… https://t.co/PQdui6WHR2
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# remukarhulahti tweeted:
# -----
# #Bitcoin is the S&amp;P500 of crypto.
#
# 90% of the casino players will under perform it each and every year.
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# educryptoart tweeted:
# -----
# Ohh yes! Finally #bitcoin #angel #nft #cryptoart #og
# @trevorjonesart https://t.co/NY2CturW2e
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# PowaaPoken tweeted:
# -----
# Stop using Bitcoin ! Try to buy 67771 $PKN instead !!! #PKN #pokmi #PokenArmy #poken #PokenArmyProgram
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# helma_1967 tweeted:
# -----
# @airdropinspect Great project and strong team I trust this project can be successfully 🔥 Let's go to the moon 🔥 🌙… https://t.co/RZNq6TGC7V
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# BitSwings tweeted:
# -----
# [1D] #Bitcoin market is strongly trending down current momentum suggests the market is neutral. #pips #stocks… https://t.co/RG7CQHomIU
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# BitSwings tweeted:
# -----
# [1h] #Bitcoin market is weakly trending up current momentum suggests the market is neutral. #forexsignals #money… https://t.co/yOBZFNIxzc
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# SenAhmet26 tweeted:
# -----
# Be sure to check out our Metaverse token project, which will mark 2022.@DexGame_io
#
# #dexgame #dxgm #metaverse #p2e… https://t.co/xDSQzTCl4i
# -----
# # of likes: 0
# # of retweets: 1
# Tweet Value: 4.983370478313047
# Account Value: 1.05
# Tweet Magnitude: 6.033370478313047
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# SharadKatiyar22 tweeted:
# -----
# MEMEPOOL in Hindi | Bitcoin Memepool |
# #BlockchainCourse
# #Episode16
#
# https://t.co/jgTQJx4EvA
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# parsehfarzad tweeted:
# -----
# @BluesparrowC @binance @BlueSparrowETH #bluesparrow always turn a negative market into a positive market, always be… https://t.co/oAowX1GyZ8
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# Hassan67198878 tweeted:
# -----
# @BluesparrowC @elonmusk @BillyM2k @BlueSparrowETH The best 1000x NFT token is #bluesparrow
# Why?
# KYC Done
# Ownership… https://t.co/SP4mD2xXS9
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Jamyies tweeted:
# -----
# RETWEET if you're a long-term holder and always buying #Bitcoin dips.
# -----
# # of likes: 1
# # of retweets: 2
# Tweet Value: 4.963789847678452
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# betincrypto tweeted:
# -----
# Bitcoin Price Surges On Massive Short Squeeze
#
# Toplist Crypto Casino &amp; SportsBook 👉 https://t.co/4RPbxhUeNy 👈
# https://t.co/nhd4Gx9A3u
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# MaxxSmithESM tweeted:
# -----
# Explaining Bitcoin to my mom &amp; dad as a 6 year old child. https://t.co/OxdAnLS7ET
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# jacobite68 tweeted:
# -----
# @AltcoinGordon Your 24m Bitcoin thesis
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# emcverse tweeted:
# -----
# @BillyM2k People who are bitcoin maxi need to take the potatoes out their butt. #Crypto is changing and evolving. https://t.co/03N1WM8V7D
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# SenAhmet26 tweeted:
# -----
# Be sure to check out our Metaverse token project, which will mark 2022.@DexGame_io
#
# #dexgame #dxgm #metaverse #p2e… https://t.co/lomFPEgOHQ
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Bitcoin_Ireland tweeted:
# -----
# #ProofOfStake is a form of consensus mechanism where #network users pool funds together (#stake) as a form of colla… https://t.co/fia8icdA7G
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Long_Irish_l_F tweeted:
# -----
# @ATLHawks @emoryhealthcare Hello, my name is Mr Irish and I wanna give my testimony from Crypto Currency Trading al… https://t.co/e1ZxmGHW2x
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# cryptoexpbot tweeted:
# -----
# 🔍 #BTC | #Bitcoin REPORT 🔍
#
# 💰 ACTUAL PRICE: 43411$
#
# 🕓 VARIATIONS:
# Hour: +0.154%
# Day: +1.102%
# Week: +5.969%
# Month: -9.98%
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# YusufTingi2 tweeted:
# -----
# @BabyDogeCoin #babydogecoin #BabyDogeArmy  is flying fasten your seat belts🚀🚀🚀
#
# #Binance #Bitcoin #ETH #cryptocurrency
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# nf4mation tweeted:
# -----
# Crypto Exchange FTX Rolls Out $2,000,000,000 Venture Fund
# #bitcoin #ethereum #cryptocurrency #blockchain #btc… https://t.co/CjmSrcfn75
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# niftyscoops tweeted:
# -----
# @PensionApesClub Done  @JTahbonemah @a1rdr0pp3r @HappyDave23 #Bitcoin #NFTCommmunity #SolanaNFTs
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# BackstreetBets tweeted:
# -----
# 31% PROFIT with #PERP in 2 hours🔥
#
# Next PUMP coin in DISCORD👇
# 👾https://t.co/qhNSeWd7hG
#
# #crypto #bitcoin #shib $xrp… https://t.co/1HHeD5CYBG
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# NFTkaStat tweeted:
# -----
# Drop your $ETH wallet address. I will send $4570 #NFT to whoever retweeted this! pinned in profile📌
# Follow me
# go t… https://t.co/fjwvGQkAOi
# -----
# # of likes: 4
# # of retweets: 1
# Tweet Value: 4.971566042522484
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# coinok tweeted:
# -----
# 1 BTC Price: Bitstamp 43414.19 USD #BTC #Bitcoin 2022-01-15 13:00 https://t.co/rFb8sKoACm
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# mr_cryptoallday tweeted:
# -----
# Current Price of DOGECOIN (DOGE): $ 0.189164, 24H Change = 0.9407471698973583 %, 24H Volume = $ 2123676862.2073495,… https://t.co/1vSjxum7lU
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Long_Irish_l_F tweeted:
# -----
# @ATLHawks Hello, my name is Mr Irish and I wanna give my testimony from Crypto Currency Trading also known as Bitco… https://t.co/QPqrAvZkDV
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# cryptodev93 tweeted:
# -----
# @Davincij15 @aantonop Ahann!! Pay your mobile bills from Quppy app!! @QuppyPay
# Top up your Mobile phone with crypto… https://t.co/utbaxvKRRg
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# parsehfarzad tweeted:
# -----
# @BluesparrowC @binance @BlueSparrowETH If you don’t choice your own investment plan, chances are you’ll fall into s… https://t.co/PKbDw3ZJL0
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# bitcoin_eagle tweeted:
# -----
# @LifeMathMoney We need more energy.
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Jessica41045661 tweeted:
# -----
# I didn't allow negative minds get to me. Nothing has meaning expect for the meaning we give it -Zig ziglar… https://t.co/JFR1tWkhOV
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# prokey_io tweeted:
# -----
# True story!
#
# Did you buy the #dip or no?
#
# #meme #cryptomeme #bitcoin https://t.co/msWzp99aWu
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# BWoodblack tweeted:
# -----
# @CalvinAyre @CharisHamilton8 @nytimes BSV is centralized trash and it's laughable people still think Craig is  Sato… https://t.co/ttX8ZXejpb
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# bmurphypointman tweeted:
# -----
# #linkedin #twitter #facebook #instagram #bitcoin #socialmedia #pinterest #medium #reddit #anniversary #gift #gifts… https://t.co/lmbr9JGCm6
# -----
# # of likes: 0
# # of retweets: 1
# Tweet Value: 4.983370478313047
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# redpillblue1 tweeted:
# -----
# This.
#
# Please be careful. Never be afraid to ask questions
#
# #Bitcoin @VisionCryptoApp https://t.co/pFqwATWp5Y
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# PlantBasedApe tweeted:
# -----
# @pdse84 @userofintellect @wilkilin008 In my opinion -
# Most stocks will squeeze, the MOASS is GME.
#
# Price potential… https://t.co/U9m38nkE51
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# CURRENT CONNOTATION: 235.64558126434505
